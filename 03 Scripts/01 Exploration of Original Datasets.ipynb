# %% [markdown]
# # Import Obesity Datasets

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Import Primary Obesity Dataset, BMI Table
obesity_bmi=pd.read_csv(r"C:\Users\miche\DA_Obesity and COVID19\02 Data\Original Data\01 Obesity BMI Table_BRFSS.csv")

# %%
# Import major Obesity Dataset, with more information than necessary
obesity_all=pd.read_csv(r"C:\Users\miche\DA_Obesity and COVID19\02 Data\Original Data\02 CDC_ Adult Obesity by State_Age.csv")

# %%
# Import minor Obesity Dataset, US Adult Obesity Rates over Time, 1995-2020
obesity_us=pd.read_csv(r"C:\Users\miche\DA_Obesity and COVID19\02 Data\Original Data\03 USAFacts_US Obesity Rates.csv")

# %% [markdown]
# ## Exploring Obesity Datasets

# %%
# Explore Primary Dataset
obesity_bmi.head()
# Out:
#    Year Locationabbr Locationdesc                         Class  \
# 0  2019           KY     Kentucky  Overweight and Obesity (BMI)
# 1  2020           AK       Alaska  Overweight and Obesity (BMI)
# 2  2020           AK       Alaska  Overweight and Obesity (BMI)
# 3  2020           AZ      Arizona  Overweight and Obesity (BMI)
# 4  2020           AR     Arkansas  Overweight and Obesity (BMI)
#
#             Topic                                           Question  \
# 0  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 1  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 2  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 3  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 4  BMI Categories  Weight classification by Body Mass Index (BMI)...
#
#                       Response        Break_Out Break_Out_Category  \
# 0   Overweight (BMI 25.0-29.9)          Overall            Overall
# ...

# %%
obesity_bmi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58538 entries, 0 to 58537
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        58538 non-null  int64
#  1   Locationabbr                58538 non-null  object
#  2   Locationdesc                58538 non-null  object
#  3   Class                       58538 non-null  object
#  4   Topic                       58538 non-null  object
#  5   Question                    58538 non-null  object
#  6   Response                    58538 non-null  object
#  7   Break_Out                   58538 non-null  object
#  8   Break_Out_Category          58538 non-null  object
#  9   Sample_Size                 58538 non-null  object
#  10  Data_value                  46912 non-null  float64
#  11  Confidence_limit_Low        46824 non-null  float64
#  12  Confidence_limit_High       46824 non-null  float64
# ...

# %%
obesity_bmi.describe()
# Out:
#                Year    Data_value  Confidence_limit_Low  \
# count  58538.000000  46912.000000          46824.000000
# mean    2016.186067     28.532598             24.424476
# std        3.147493     12.310507             11.324086
# min     2011.000000      0.300000              0.100000
# 25%     2014.000000     25.990000             20.700000
# 50%     2016.000000     31.550000             27.120000
# 75%     2019.000000     36.000000             32.000000
# max     2021.000000     70.460000             60.620000
#
#        Confidence_limit_High    LocationID
# count           46824.000000  58538.000000
# mean               32.654122     30.768936
# std                14.008932     17.575035
# min                 0.500000      1.000000
# 25%                29.700000     17.000000
# 50%                35.790000     30.000000
# 75%                40.430000     44.000000
# max                83.770000     99.000000

# %%
obesity_bmi.shape
# Out:
# (58538, 27)

# %%
obesity_bmi.columns
# Out:
# Index(['Year', 'Locationabbr', 'Locationdesc', 'Class', 'Topic', 'Question',
#        'Response', 'Break_Out', 'Break_Out_Category', 'Sample_Size',
#        'Data_value', 'Confidence_limit_Low', 'Confidence_limit_High',
#        'Display_order', 'Data_value_unit', 'Data_value_type',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'DataSource',
#        'ClassId', 'TopicId', 'LocationID', 'BreakoutID', 'BreakOutCategoryID',
#        'QuestionID', 'ResponseID', 'GeoLocation'],
#       dtype='object')

# %%
# Explore major obesity dataset
obesity_all.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2020     2020           US     National
# 1       2014     2014           GU         Guam
# 2       2013     2013           US     National
# 3       2013     2013           US     National
# 4       2015     2015           US     National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System        Physical Activity
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0  Physical Activity - Behavior
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3       Obesity / Weight Status
# 4  Physical Activity - Behavior
#
# ...

# %%
obesity_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80929 entries, 0 to 80928
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   80929 non-null  int64
#  1   YearEnd                     80929 non-null  int64
#  2   LocationAbbr                80929 non-null  object
#  3   LocationDesc                80929 non-null  object
#  4   Datasource                  80929 non-null  object
#  5   Class                       80929 non-null  object
#  6   Topic                       80929 non-null  object
#  7   Question                    80929 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             80929 non-null  object
#  10  Data_Value                  72965 non-null  float64
#  11  Data_Value_Alt              72965 non-null  float64
#  12  Data_Value_Footnote_Symbol  7964 non-null   object
# ...

# %%
obesity_all.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Unit    Data_Value  \
# count  80929.000000  80929.000000              0.0  72965.000000
# mean    2015.536717   2015.536717              NaN     31.238672
# std        2.841623      2.841623              NaN     10.156464
# min     2011.000000   2011.000000              NaN      0.900000
# 25%     2013.000000   2013.000000              NaN     24.400000
# 50%     2016.000000   2016.000000              NaN     31.100000
# 75%     2018.000000   2018.000000              NaN     36.900000
# max     2020.000000   2020.000000              NaN     77.600000
#
#        Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   \
# count    72965.000000          72965.000000            72965.000000
# mean        31.238672             26.933101               36.109866
# std         10.156464              9.960837               11.084842
# min          0.900000              0.300000                3.000000
# ...

# %%
obesity_all.shape
# Out:
# (80929, 33)

# %%
obesity_all.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# Explore minor obesity dataset
obesity_us.head()
# Out:
#                                 Years   1995   1996   1997   1998   1999  \
# 0  Percent of adults with obesity (%)  0.158  0.168  0.166  0.183  0.198
# 1                        By age group    NaN    NaN    NaN    NaN    NaN
# 2                         18 - 24 (%)    NaN    NaN    NaN    NaN    NaN
# 3                         25 - 34 (%)    NaN    NaN    NaN    NaN    NaN
# 4                         35 - 44 (%)    NaN    NaN    NaN    NaN    NaN
#
#     2000   2001   2002   2003  ...      2011      2012      2013      2014  \
# 0  0.201  0.211  0.222  0.228  ...  0.278000  0.276000  0.294000  0.296000
# 1    NaN    NaN    NaN    NaN  ...       NaN       NaN       NaN       NaN
# 2    NaN    NaN    NaN    NaN  ...  0.156449  0.158255  0.159340  0.163078
# 3    NaN    NaN    NaN    NaN  ...  0.261784  0.261725  0.271686  0.279784
# 4    NaN    NaN    NaN    NaN  ...  0.307529  0.315275  0.323471  0.331255
#
#        2015      2016      2017      2018     2019      2020
# ...

# %%
obesity_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Years   188 non-null    object
#  1   1995    3 non-null      object
#  2   1996    4 non-null      object
#  3   1997    3 non-null      object
#  4   1998    4 non-null      object
#  5   1999    3 non-null      object
#  6   2000    4 non-null      object
#  7   2001    3 non-null      object
#  8   2002    2 non-null      float64
#  9   2003    2 non-null      float64
#  10  2004    2 non-null      float64
#  11  2005    2 non-null      float64
#  12  2006    2 non-null      float64
#  13  2007    2 non-null      float64
#  14  2008    2 non-null      float64
#  15  2009    2 non-null      float64
#  16  2010    2 non-null      float64
#  17  2011    180 non-null    float64
#  18  2012    180 non-null    float64
#  19  2013    180 non-null    float64
#  20  2014    180 non-null    float64
# ...

# %%
obesity_us.describe()
# Out:
#            2002      2003      2004     2005      2006      2007      2008  \
# count  2.000000  2.000000  2.000000  2.00000  2.000000  2.000000  2.000000
# mean   0.221000  0.228500  0.237500  0.24050  0.249000  0.264500  0.264000
# std    0.001414  0.000707  0.007778  0.00495  0.002828  0.002121  0.002828
# min    0.220000  0.228000  0.232000  0.23700  0.247000  0.263000  0.262000
# 25%    0.220500  0.228250  0.234750  0.23875  0.248000  0.263750  0.263000
# 50%    0.221000  0.228500  0.237500  0.24050  0.249000  0.264500  0.264000
# 75%    0.221500  0.228750  0.240250  0.24225  0.250000  0.265250  0.265000
# max    0.222000  0.229000  0.243000  0.24400  0.251000  0.266000  0.266000
#
#            2009      2010        2011        2012        2013        2014  \
# count  2.000000  2.000000  180.000000  180.000000  180.000000  180.000000
# mean   0.273500  0.275500    0.276045    0.279371    0.286679    0.292183
# ...

# %%
obesity_us.shape
# Out:
# (190, 27)

# %%
obesity_us.columns
# Out:
# Index(['Years', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %% [markdown]
# # Import COVID-19 Death Datasets

# %%
# Import Primary COVID Death Dataset, by state and age
covid=pd.read_csv(r"C:\Users\miche\DA_Obesity and COVID19\02 Data\Original Data\04 CDC_ COVID Deaths by State_Age.csv")
# Out:
# C:\Users\miche\AppData\Local\Temp\ipykernel_11204\409131553.py:2: DtypeWarning: Columns (12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   covid=pd.read_csv(r"C:\Users\miche\DA_Obesity and COVID19\02 Data\Original Data\04 CDC_ COVID Deaths by State_Age.csv")

# %%
# Import backup COVID Death Dataset, by state over time
covid_time=pd.read_csv(r"C:\Users\miche\DA_Obesity and COVID19\02 Data\Original Data\05 CDC_COVID Deaths by State_Time_ARCHIVED.csv")

# %% [markdown]
# ## Explore COVID Death Datasets

# %%
# Explore Primary Death Dataset
covid.head()
# Out:
#    Data as of  Start Date    End Date     Group  Year  Month  HHS Region  \
# 0  11/16/2022  01/01/2020  11/12/2022  By Total   NaN    NaN           0
# 1  11/16/2022  01/01/2020  11/12/2022  By Total   NaN    NaN           0
# 2  11/16/2022  01/01/2020  11/12/2022  By Total   NaN    NaN           0
# 3  11/16/2022  01/01/2020  11/12/2022  By Total   NaN    NaN           0
# 4  11/16/2022  01/01/2020  11/12/2022  By Total   NaN    NaN           0
#
#            State               Place of Death    Age group COVID-19 Deaths  \
# 0  United States  Total - All Places of Death     All Ages       1,069,802
# 1  United States  Total - All Places of Death   0-17 years           1,360
# 2  United States  Total - All Places of Death  18-29 years           6,675
# 3  United States  Total - All Places of Death  30-39 years          19,093
# 4  United States  Total - All Places of Death  40-49 years          44,783
#
#   Total Deaths Pneumonia Deaths Pneumonia and COVID-19 Deaths  \
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170586 entries, 0 to 170585
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Data as of                                170586 non-null  object
#  1   Start Date                                170586 non-null  object
#  2   End Date                                  170586 non-null  object
#  3   Group                                     170586 non-null  object
#  4   Year                                      166212 non-null  float64
#  5   Month                                     153090 non-null  float64
#  6   HHS Region                                170586 non-null  int64
#  7   State                                     170586 non-null  object
#  8   Place of Death                            170586 non-null  object
#  9   Age group                                 170586 non-null  object
# ...

# %%
covid.describe()
# Out:
#                 Year          Month     HHS Region
# count  166212.000000  153090.000000  170586.000000
# mean     2020.973684       6.342857       5.111111
# std         0.810683       3.371682       2.813117
# min      2020.000000       1.000000       0.000000
# 25%      2020.000000       3.000000       3.000000
# 50%      2021.000000       6.000000       5.000000
# 75%      2022.000000       9.000000       8.000000
# max      2022.000000      12.000000      10.000000

# %%
covid.shape
# Out:
# (170586, 17)

# %%
covid.columns
# Out:
# Index(['Data as of', 'Start Date', 'End Date', 'Group', 'Year', 'Month',
#        'HHS Region', 'State', 'Place of Death', 'Age group', 'COVID-19 Deaths',
#        'Total Deaths', 'Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths',
#        'Influenza Deaths', 'Pneumonia, Influenza, or COVID-19 Deaths',
#        'Footnote'],
#       dtype='object')

# %%
# Explore Archived Deaths Dataset
covid_time.head()
# Out:
#   submission_date state tot_cases conf_cases prob_cases new_case pnew_case  \
# 0      03/11/2021    KS   297,229    241,035     56,194        0         0
# 1      12/01/2021    ND   163,565    135,705     27,860      589       220
# 2      01/02/2022    AS        11        NaN        NaN        0         0
# 3      11/22/2021    AL   841,461    620,483    220,978      703       357
# 4      05/30/2022    AK   251,425        NaN        NaN        0         0
#
#   tot_death conf_death prob_death new_death pnew_death  \
# 0     4,851        NaN        NaN         0          0
# 1     1,907        NaN        NaN         9          0
# 2         0        NaN        NaN         0          0
# 3    16,377     12,727      3,650         7          3
# 4     1,252        NaN        NaN         0          0
#
#                created_at consent_cases consent_deaths
# 0  03/12/2021 03:20:13 PM         Agree            NaN
# 1  12/02/2021 02:35:20 PM         Agree      Not agree
# ...

# %%
covid_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60060 entries, 0 to 60059
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   submission_date  60060 non-null  object
#  1   state            60060 non-null  object
#  2   tot_cases        60060 non-null  object
#  3   conf_cases       34034 non-null  object
#  4   prob_cases       33962 non-null  object
#  5   new_case         60060 non-null  object
#  6   pnew_case        56534 non-null  object
#  7   tot_death        60060 non-null  object
#  8   conf_death       33273 non-null  object
#  9   prob_death       33273 non-null  object
#  10  new_death        60060 non-null  object
#  11  pnew_death       56566 non-null  object
#  12  created_at       60060 non-null  object
#  13  consent_cases    50045 non-null  object
#  14  consent_deaths   51051 non-null  object
# dtypes: object(15)
# memory usage: 6.9+ MB

# %%
covid_time.describe()
# Out:
#        submission_date  state tot_cases conf_cases prob_cases new_case  \
# count            60060  60060     60060      34034      33962    60060
# unique            1001     60     43020      26174      19304     8125
# top         03/11/2021     KS         0          0          0        0
# freq                60   1001      4117       1044       7491    14266
#
#        pnew_case tot_death conf_death prob_death new_death pnew_death  \
# count      56534     60060      33273      33273     60060      56566
# unique      3269     19165      14171       4417       506        324
# top            0         0          0          0         0          0
# freq       27762      6573       2345       8622     23544      40905
#
#                     created_at consent_cases consent_deaths
# count                    60060         50045          51051
# unique                    2224             2              2
# top     03/26/2020 04:22:39 PM         Agree          Agree
# ...

# %%
covid_time.shape
# Out:
# (60060, 15)
