# %% [markdown]
# # Import Libraries and Datasets

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Import prepared population data set; includes population estimates by state from 2010 - 2022
pop = pd.read_csv(r"C:\Users\miche\DA_Obesity and COVID19\02 Data\Prepared Data\04.03 CENSUS 2010_2022.csv")

# %%
# Import prepared COVID Deaths by state from 2020 - 2022
covid = pd.read_csv(r"C:\Users\miche\DA_Obesity and COVID19\02 Data\Prepared Data\03.02 COVID Deaths_final.csv")

# %% [markdown]
# # Review Data
# ### population

# %%
pop.head()
# Out:
#         State  2010 Population  2011 Population  2012 Population   \
# 0     Alabama          4779736          4799069           4815588
# 1      Alaska           710231           722128            730443
# 2     Arizona          6392017          6472643           6554978
# 3    Arkansas          2915918          2940667           2952164
# 4  California         37253956         37638369          37948800
#
#    2013 Population  2014 Population  2015 Population  2016 Population  \
# 0          4830081          4841799          4852347          4863525
# 1           737068           736283           737498           741456
# 2          6632764          6730413          6829676          6941072
# 3          2959400          2967392          2978048          2989918
# 4         38260787         38596972         38918045         39167117
#
#    2017 Population  2018 Population  2019 Population  2020 Population  \
# 0          4874486          4887681          4903185          5024279
# ...

# %%
pop.columns
# Out:
# Index(['State', '2010 Population', '2011 Population', '2012 Population ',
#        '2013 Population', '2014 Population', '2015 Population',
#        '2016 Population', '2017 Population', '2018 Population',
#        '2019 Population', '2020 Population', '2021 Population',
#        '2022 Population'],
#       dtype='object')

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   2010 Population   51 non-null     int64
#  2   2011 Population   51 non-null     int64
#  3   2012 Population   51 non-null     int64
#  4   2013 Population   51 non-null     int64
#  5   2014 Population   51 non-null     int64
#  6   2015 Population   51 non-null     int64
#  7   2016 Population   51 non-null     int64
#  8   2017 Population   51 non-null     int64
#  9   2018 Population   51 non-null     int64
#  10  2019 Population   51 non-null     int64
#  11  2020 Population   51 non-null     int64
#  12  2021 Population   51 non-null     int64
#  13  2022 Population   51 non-null     int64
# dtypes: int64(13), object(1)
# memory usage: 5.7+ KB

# %%
pop.describe()
# Out:
#        2010 Population  2011 Population  2012 Population   2013 Population  \
# count     5.100000e+01     5.100000e+01      5.100000e+01     5.100000e+01
# mean      6.053834e+06     6.108958e+06      6.153549e+06     6.195955e+06
# std       6.823984e+06     6.901810e+06      6.967073e+06     7.029241e+06
# min       5.636260e+05     5.672990e+05      5.763050e+05     5.821220e+05
# 25%       1.696962e+06     1.712291e+06      1.724314e+06     1.732560e+06
# 50%       4.339367e+06     4.369821e+06      4.386346e+06     4.404659e+06
# 75%       6.636084e+06     6.720105e+06      6.780032e+06     6.838650e+06
# max       3.725396e+07     3.763837e+07      3.794880e+07     3.826079e+07
#
#        2014 Population  2015 Population  2016 Population  2017 Population  \
# count     5.100000e+01     5.100000e+01     5.100000e+01     5.100000e+01
# mean      6.241196e+06     6.286964e+06     6.332183e+06     6.372265e+06
# ...

# %%
pop.shape
# Out:
# (51, 14)

# %% [markdown]
# ### COVID deaths

# %%
covid.head()
# Out:
#         State  2020 COVID-19 Deaths  2020 COVID-Like Deaths  \
# 0     Alabama                  6706                    9870
# 1      Alaska                   254                     434
# 2     Arizona                  9321                   13237
# 3    Arkansas                  4027                    6215
# 4  California                 33578                   52630
#
#    2021 COVID-19 Deaths  2021 COVID-Like Deaths  2022 COVID-19 Deaths  \
# 0                  9719                   12496                  3947
# 1                   839                    1005                   311
# 2                 14060                   17518                  5172
# 3                  5336                    7264                  2558
# 4                 48327                   64106                 19836
#
#    2022 COVID-Like Deaths
# 0                    6134
# 1                     478
# 2                    7994
# 3                    4188
# 4                   33271

# %%
covid.columns
# Out:
# Index(['State', '2020 COVID-19 Deaths', '2020 COVID-Like Deaths',
#        '2021 COVID-19 Deaths', '2021 COVID-Like Deaths',
#        '2022 COVID-19 Deaths', '2022 COVID-Like Deaths'],
#       dtype='object')

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   51 non-null     object
#  1   2020 COVID-19 Deaths    51 non-null     int64
#  2   2020 COVID-Like Deaths  51 non-null     int64
#  3   2021 COVID-19 Deaths    51 non-null     int64
#  4   2021 COVID-Like Deaths  51 non-null     int64
#  5   2022 COVID-19 Deaths    51 non-null     int64
#  6   2022 COVID-Like Deaths  51 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
covid.describe()
# Out:
#        2020 COVID-19 Deaths  2020 COVID-Like Deaths  2021 COVID-19 Deaths  \
# count             51.000000               51.000000             51.000000
# mean            7125.156863            10553.274510           8904.647059
# std             7578.975573            11160.936414          10659.253307
# min              145.000000              428.000000            308.000000
# 25%             1634.500000             2575.000000           2305.000000
# 50%             5162.000000             7977.000000           5907.000000
# 75%             9055.000000            13804.000000           9886.500000
# max            33578.000000            52630.000000          48786.000000
#
#        2021 COVID-Like Deaths  2022 COVID-19 Deaths  2022 COVID-Like Deaths
# count               51.000000             51.000000               51.000000
# mean             11837.450980           4279.058824             6792.901961
# ...

# %%
covid.shape
# Out:
# (51, 7)

# %% [markdown]
# # Merge COVID-19 Death and Population datasets
# #### Using a full outer join

# %%
# Test merge without overwriting
pd.merge(covid,pop, on = ['State'], indicator = True)
# Out:
#                    State  2020 COVID-19 Deaths  2020 COVID-Like Deaths  \
# 0                Alabama                  6706                    9870
# 1                 Alaska                   254                     434
# 2                Arizona                  9321                   13237
# 3               Arkansas                  4027                    6215
# 4             California                 33578                   52630
# 5               Colorado                  5073                    7297
# 6            Connecticut                  6298                    7977
# 7               Delaware                  1096                    1577
# 8   District of Columbia                  1004                    1429
# 9                Florida                 21827                   35229
# 10               Georgia                 10454                   15137
# 11                Hawaii                   365                    1045
# ...

# %%
# Commit merge
covid_rate=pop.merge(covid, on=['State'], indicator=True)

# %%
covid_rate.head()
# Out:
#         State  2010 Population  2011 Population  2012 Population   \
# 0     Alabama          4779736          4799069           4815588
# 1      Alaska           710231           722128            730443
# 2     Arizona          6392017          6472643           6554978
# 3    Arkansas          2915918          2940667           2952164
# 4  California         37253956         37638369          37948800
#
#    2013 Population  2014 Population  2015 Population  2016 Population  \
# 0          4830081          4841799          4852347          4863525
# 1           737068           736283           737498           741456
# 2          6632764          6730413          6829676          6941072
# 3          2959400          2967392          2978048          2989918
# 4         38260787         38596972         38918045         39167117
#
#    2017 Population  2018 Population  ...  2020 Population  2021 Population  \
# ...

# %%
covid_rate.describe()
# Out:
#        2010 Population  2011 Population  2012 Population   2013 Population  \
# count     5.100000e+01     5.100000e+01      5.100000e+01     5.100000e+01
# mean      6.053834e+06     6.108958e+06      6.153549e+06     6.195955e+06
# std       6.823984e+06     6.901810e+06      6.967073e+06     7.029241e+06
# min       5.636260e+05     5.672990e+05      5.763050e+05     5.821220e+05
# 25%       1.696962e+06     1.712291e+06      1.724314e+06     1.732560e+06
# 50%       4.339367e+06     4.369821e+06      4.386346e+06     4.404659e+06
# 75%       6.636084e+06     6.720105e+06      6.780032e+06     6.838650e+06
# max       3.725396e+07     3.763837e+07      3.794880e+07     3.826079e+07
#
#        2014 Population  2015 Population  2016 Population  2017 Population  \
# count     5.100000e+01     5.100000e+01     5.100000e+01     5.100000e+01
# mean      6.241196e+06     6.286964e+06     6.332183e+06     6.372265e+06
# ...

# %%
covid_rate.columns
# Out:
# Index(['State', '2010 Population', '2011 Population', '2012 Population ',
#        '2013 Population', '2014 Population', '2015 Population',
#        '2016 Population', '2017 Population', '2018 Population',
#        '2019 Population', '2020 Population', '2021 Population',
#        '2022 Population', '2020 COVID-19 Deaths', '2020 COVID-Like Deaths',
#        '2021 COVID-19 Deaths', '2021 COVID-Like Deaths',
#        '2022 COVID-19 Deaths', '2022 COVID-Like Deaths', '_merge'],
#       dtype='object')

# %%
covid_rate.shape
# Out:
# (51, 21)

# %%
covid_rate['_merge'].value_counts()
# Out:
# both          51
# left_only      0
# right_only     0
# Name: _merge, dtype: int64

# %% [markdown]
# ## Merge Successful

# %%
# Export data where the COVID-19 death rate will be calculated by state, for each year of the COVID-19 pandemic.
covid_rate.to_csv(r"C:\Users\miche\DA_Obesity and COVID19\02 Data\Prepared Data\03.03 COVID_CENSUS.csv")
